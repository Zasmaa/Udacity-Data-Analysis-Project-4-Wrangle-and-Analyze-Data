# %% [markdown]
# ## Project: Wrangle and Analyze Data
# This is an outline of the project 4.
#
# **I.	Introduction**
#
# a.	The goal of this project is to understand how to gather, assess, and clean data. In this particular project, we gather data from different sources.  The source was twitter API,  Udacity’s servers and tweet archive from twitter user dog rates.
# **II.	Gather Data**
#
# a.	Import all library required for this project.
# b.	Request the URL from the Udacity’s servers and essential into a data Frame, this particular file is in .tsv format. Make sure to ad “sep = \t”
# c.	Then query the Twitter API by getting your consumer key, consumer secret, access token, and access secret.
# d.	Also, get the twitter-archive-enhance.csv into a data-Frame. Then create a JSON file and dump the twitter archive CSV into the JSON
# e.	The last step is to create a data-Fram from the JSON.
# III.	Assess Data
# a.	They assess that data is split into two-part.
# b.	The first one is a visual assessment
# i.	This part will look at the whole data frame to see were to clean as a whole.
# ii.
# c.	The second one is the Programmatic Assessment.
# i.	This will use a code to look into the quality and tidiness of the data.
# ii.	Some of the codes use is
# 1.	Info()- to see the data type and non-null
# 2.	Describe – to see the mean, std, min, and max.
# 3.	Sample ()- to see the last five of the data
# 4.	Duplicated
# iii. Make a note for each mistake that needs to be clean. Separate into quality and tidiness.
#
# **IV.	Clean Data**
#
# a.	Create a copy of the original data
# b.	Clean each a mistake by define, then code corrections  and last test to see if everything is correct.
# i.
#
# **V.	Analyzing and visualizing data**
#
# a.	Analyze your data and make graphs
#
# **VI.	Conclusions.**
#
# a.	Describe the results
#
# This  part is the list of mistakes I found in the data.
#
# #### Quality
#
# ##### `df  image-predictions` table
# - not all are dog ratings ( keeping the original tweeted of dogs)
# -  duplicated in jpg_url column
# - capitalize the headers or rename it
#
#
#
# ##### `df_2 : twitter-archive-enhanced` table
#
#
# - take out in_reply_to_user_id and in_reply_to_status_id
# - take out the Rtweeted_status_timestamp.
# - capitalize the headers or rename it
# - remove the "+ " in timestamp
#
# - duplicated in expanded_urls
#
# - timestamp should be in python's Datetime
# - drop None and a in column name
#
#
#
#
#
#
#
#
#
# ##### `df 3` table
# - capitalize the headers
#
#
# #### Tidiness
#
# ##### `df  image-predictions` table
#
# - make the dog  breeds one column
#
# ##### `df_2 : twitter-archive-enhanced` table
# - make the dog "stage" one column
#
#
# ##### `df 3` table
#  - merge  df_2 and df3 tables.
#
#
#
# •
#
# Analyzing and Visualizing Data
# 1.	What is most dog name type
# 2.	What is the most dog type
# 3.	What is the most retweet
# 4.	Who tweets the most
#
# Results
# 1.	The first insights show that the “pupper” is the most dog stage.
# 2.	The second insights show that the Labrador retriever is the most dog breeds.
# 3.	The third insights show that most retweet is 79515.000000.
# 4.	The fourth insights show that there is no one with the most tweet.
